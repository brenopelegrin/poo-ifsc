# %%
import main as utils
import imp
imp.reload(utils)
Image = utils.Image

# %%
import matplotlib.pyplot as plt

# %%
imgInput = Image(fromFile=True, filePath='/home/brenopelegrin/usp/poo/poo-ifsc/projeto2/venv/input/gourds.pgm')
imgNew = imgInput.median(k=13)
#imgInput.saveToPGM('/home/brenopelegrin/usp/poo/poo-ifsc/projeto2/venv/input/test_gourds.pgm')

# %%
plt.imshow(imgNew.getPixels(), cmap='gray', vmin=0, vmax=255)

# %%
imgOutput = Image(fromFile=True, filePath='./output/gourds_median_k13.pgm')

# %%
plt.imshow(imgOutput.getPixels(), cmap='gray', vmin=0, vmax=255)

# %%
def test(inputImage):
    os.system('python3 main.py --imgpath ./gourds.pgm --op mean --k 5 --outputpath ./output/')

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/home/brenopelegrin/usp/poo/poo-ifsc/projeto2/venv/input/chest.pgm',-1)

# %%
img
# Out:
# array([[216, 223, 229, ..., 201, 199, 201],
#        [216, 223, 229, ..., 201, 199, 201],
#        [216, 223, 229, ..., 201, 199, 201],
#        ...,
#        [ 62,  54,  46, ..., 174, 174, 171],
#        [ 61,  55,  48, ..., 171, 180, 180],
#        [ 56,  52,  47, ..., 183, 180, 160]], dtype=uint8)

# %%
imgInput = Image(fromFile=True, filePath='/home/brenopelegrin/usp/poo/poo-ifsc/projeto2/venv/input/chest.pgm')

# %%
imgTest = np.array(imgInput.getPixels())

# %%
imgTest.shape
# Out:
# (348, 620)

# %%
img.shape
# Out:
# (348, 620)
